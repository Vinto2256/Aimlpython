# %%
print("HI")
# Out:
# HI

# %%
print("HELLO")
# Out:
# HELLO

# %%
a = 30
b = 20
c = a+b
print("Sum:", c)
# Out:
# Sum: 50

# %%
print("HELLO")
a = 5
b = 10
c = a+b
print("Sum:", c)
# Out:
# HELLO
# Sum: 15

# %%
d={'a':5, 'b':6}
print(d.keys(), d.values())
# Out:
# dict_keys(['a', 'b']) dict_values([5, 6])

# %%
d1={'Name':'Vinto', 'Age':20}
d1['Name']
d1['Age']
d1
# Out:
# {'Name': 'Vinto', 'Age': 20}

# %%
def add(a, b):   #userdefined function
    print(a + b)

# %%
add(5,3)
# Out:
# 8

# %%
sum([4,5,6]) #built-in function
# Out:
# 15

# %%
def multiply(x, y):
    return x*y

# %% [markdown]
# print(multiply(4, 5))

# %%
def calculate_area(length,width):
    """Calculates the area of a rectangle"""
    area=length*width
    return area

# %%
room_area=calculate_area(10,5)
print(f"Room area:{room_area}square meters")
# Out:
# Room area:50square meters
