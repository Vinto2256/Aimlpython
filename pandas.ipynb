# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\vinto\appdata\local\programs\python\python312\lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vinto\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vinto\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\vinto\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in c:\users\vinto\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {'Name': ['Vinto', 'Vithu'], 'Age': [20, 19]}
df = pd.DataFrame(data)

# %%
lst = [['Vinto', 20], ['Vithu', 19]]
df = pd.DataFrame(lst, columns=['Name', 'Age'])

# %%
df.head()
# Out:
#     Name  Age
# 0  Vinto   20
# 1  Vithu   19

# %%
df.tail()
# Out:
#     Name  Age
# 0  Vinto   20
# 1  Vithu   19

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   19.500000
# std     0.707107
# min    19.000000
# 25%    19.250000
# 50%    19.500000
# 75%    19.750000
# max    20.000000

# %%
df['Name']
df[['Name', 'Age']]
# Out:
#     Name  Age
# 0  Vinto   20
# 1  Vithu   19

# %%
df.loc[0]
df.iloc[1]
# Out:
# Name    Vithu
# Age        19
# Name: 1, dtype: object

# %%
df[df['Age'] > 25]
# Out:
# Empty DataFrame
# Columns: [Name, Age]
# Index: []

# %%
df['Gender'] = ['F', 'M']

# %%
df.drop('Age', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df.drop('Age', axis=1, inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
#    4631             if labels is not None:
# -> 4632                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4633
#    4634         if inplace:
#    4635             self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4674, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4670                 if not isinstance(axis, MultiIndex):
#    4671                     raise AssertionError("axis must be a MultiIndex")
#    4672                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4673             else:
# -> 4674                 new_axis = axis.drop(labels, errors=errors)
#    4675             indexer = axis.get_indexer(new_axis)
#    4676
#    4677         # Case for non-unique axis
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['Age'] not found in axis"

# %%
df.isnull()
# Out:
#    Gender
# 0   False
# 1   False

# %%
df.dropna()
# Out:
#   Gender
# 0      F
# 1      M

# %%
df.fillna(0)
# Out:
#   Gender
# 0      F
# 1      M

# %%
df.groupby('Gender') ['Age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df.groupby('Gender') ['Age'].mean()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# --> 228         raise KeyError(f"Column not found: {key}")
#     229     ndim = self.obj[key].ndim
#     230     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: Age'

# %%
df = pd.read_csv('data.csv')

# %%
df.to_csv('output.csv', index=False)

# %%
df.sort_values('Age')

# %%
df['Age'].apply9lambda x: x + 1)

# %%
df['Name'].unique()

# %%
df['Age'].value_counts()

# %%
df.drop('Age', axis=1, inplace=True)

# %%
df.isnull()

# %%
import pandas as pd

# %%
In [3]: s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
In [4]: s
Out[4]:
